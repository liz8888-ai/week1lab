# %% [markdown]
# <a href="https://colab.research.google.com/github/liz8888-ai/week1lab/blob/main/week1lab_lz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Laziza"

# %%
my_enrollment_number = "A85204925001"

# %%
my_hobby = "Swimming, skating"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Laziza, and my my enrollment number is A85404925001. I like Swimming, skating.
